# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("dijkstra.csv")
df_columns = df.keys()
df.head()
# Out:
#    nodes   serial_time   parallel_2_threads   parallel_4_threads  \
# 0    100           160                  334                  411
# 1    250           444                  823                  793
# 2    500          1326                 2263                 1642
# 3   1000          6745                 5058                 3355
# 4   1500         13869                 8879                 6478
#
#     parallel_6_threads   parallel_8_threads   parallel_10_threads  \
# 0                  433                  489                   687
# 1                  820                 1096                  1104
# 2                 1619                 2113                  2350
# 3                 3694                 5483                 11863
# 4                 8149                 8544                  9145
#
#     parallel_12_threads
# 0                  1654
# 1                  1426
# 2                 11705
# 3                 18491
# 4                 21366

# %%
df.plot(x=df_columns[0], y=df_columns[1:], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes')
plt.ylabel('Time Taken')
plt.title('Dijkstra\'s Algorithm - Time taken for different number of threads', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Dijkstra - 2 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[2]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Dijkstra\'s Algorithm - Serial vs Parallel Execution Time', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Dijkstra - 4 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[3]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Dijkstra\'s Algorithm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Dijkstra - 6 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[4]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Dijkstra\'s Algorithm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Dijkstra - 8 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[5]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Dijkstra\'s Algorithm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Dijkstra - 10 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[6]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Dijkstra\'s Algorithm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %%
# Serial vs Parallel Dijkstra - 12 Threads
df.plot(x=df_columns[0], y=[df_columns[1], df_columns[7]], kind="line", marker="o")
plt.xticks(rotation=25)
plt.xlabel('Number of nodes (N)')
plt.ylabel('Time Taken (us)')
plt.title('Dijkstra\'s Algorithm - Serial vs Parallel Execution Time ', fontsize=20)
plt.grid()
plt.legend()
plt.show()
